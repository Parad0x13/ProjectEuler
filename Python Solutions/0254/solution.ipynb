# %%
#Practically solved, but takes TOOOOOO long to brute-force equation!

factorials = []
def genFactorials(maxVal):
    value = 1
    for x in range(0, maxVal):
        value = 1
        for y in range(1, x+1):
            value *= y
        factorials.append(value)

genFactorials(11)

#Actually Slower
def findNumLen(n):
    value = n
    length = 1
    while 1:
        value /= 10
        if value > 0: length += 1
        else: return length

def fact(n):
    value = 1
    for x in range(1, n + 1): value *= x
    return value

def f(n):
    value = 0
    lenstrn = len(str(n))
#    lenstrn = findNumLen(n)
    strn = str(n)
    for x in range(lenstrn):
        value += factorials[int(strn[x])]
    return value

def sf(n):
    value = 0
    fn = f(n)
    lenstrfn = len(str(fn))
#    lenstrfn = findNumLen(f(n))
    strfn = str(fn)
    for x in range(lenstrfn):
        value += int(strfn[x])
    return value

def g(i):
    value = 0
    while sf(value) != i:
        value += 1
    return value

def sg(i):
    value = 0
    gi = g(i)
    strgi = str(gi)
    lenstrgi = len(strgi)
#    lenstrgi = findNumLen(gi)
    for x in range(lenstrgi):
        value += int(strgi[x])
    return value

def calculateValue():
    thisValue = 1
    for i in range(1, 151):
        print("Range = {}, Value = {}".format(i, thisValue))
        thisValue += sg(i)
    print("Finished")
    print(thisValue)

print("Calculating...")
print("May not give correct answer yet...")

#import cProfile
#cProfile.run('calculateValue()')
calculateValue()
# Out:
# Calculating...
# May not give correct answer yet...
# Range = 1, Value = 1
# Range = 2, Value = 1
# Range = 3, Value = 3
# Range = 4, Value = 8
# Range = 5, Value = 14
# Range = 6, Value = 21
# Range = 7, Value = 24
# Range = 8, Value = 28
# Range = 9, Value = 33
# Range = 10, Value = 39
# Range = 11, Value = 46
# Range = 12, Value = 54
# Range = 13, Value = 62
# Range = 14, Value = 71
# Range = 15, Value = 84
# Range = 16, Value = 93
# Range = 17, Value = 103
# Range = 18, Value = 114
# Range = 19, Value = 127
# Range = 20, Value = 141
# Range = 21, Value = 156
# Range = 22, Value = 172
# Range = 23, Value = 189
# Range = 24, Value = 207
# Range = 25, Value = 220
# Range = 26, Value = 234
# Range = 27, Value = 249
# Range = 28, Value = 258
# Range = 29, Value = 268
# Range = 30, Value = 279
# Range = 31, Value = 291
# Range = 32, Value = 304
# Range = 33, Value = 318
# Range = 34, Value = 330
# Range = 35, Value = 343
# Range = 36, Value = 357
# Range = 37, Value = 372
# Range = 38, Value = 391
# Range = 39, Value = 419
# Range = 40, Value = 443
# Range = 41, Value = 468
# Range = 42, Value = 505
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-acf29380e271> in <module>()
#      74 #import cProfile
#      75 #cProfile.run('calculateValue()')
# ---> 76 calculateValue()
#
# <ipython-input-2-acf29380e271> in calculateValue()
#      65     for i in range(1, 151):
#      66         print("Range = {}, Value = {}".format(i, thisValue))
# ---> 67         thisValue += sg(i)
#      68     print("Finished")
#      69     print(thisValue)
#
# <ipython-input-2-acf29380e271> in sg(i)
#      53 def sg(i):
#      54     value = 0
# ---> 55     gi = g(i)
#      56     strgi = str(gi)
#      57     lenstrgi = len(strgi)
#
# <ipython-input-2-acf29380e271> in g(i)
#      47 def g(i):
#      48     value = 0
# ---> 49     while sf(value) != i:
#      50         value += 1
#      51     return value
#
# <ipython-input-2-acf29380e271> in sf(n)
#      38     value = 0
#      39     fn = f(n)
# ---> 40     lenstrfn = len(str(fn))
#      41 #    lenstrfn = findNumLen(f(n))
#      42     strfn = str(fn)
#
# KeyboardInterrupt:
